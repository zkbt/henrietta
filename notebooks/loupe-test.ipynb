# %%
# %matplotlib -l
# if notebook interactive plotting doesn't work, try
# `%matplotlib qt5`
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'inline', 'ipympl', 'widget']

# %%
# %matplotlib notebook

from henrietta.photometry.loupe import Loupe
from henrietta.photometry.cartoons import create_test_array
import matplotlib.pyplot as plt

# %%
# make a test image
image = create_test_array()[0]

# %%
# run the interactive photometer on it
p = Loupe(image)
# Out:
# <img src="data:image/png;base64,..." width="500">
# Please [a]dd or [z]ap an aperture at the cursor location.
# ...

# %%
# the photometry is stored as a table inside this object
p.measurements
# Out:
# <QTable length=4>
#  name       xcenter           ycenter          aperture_sum
#               pix               pix
#  str6       float64           float64            float64
# ------ ----------------- ------------------ ------------------
# Star 0 45.83333188837226  73.22443181818183 1024.4139706582655
# Star 3 64.01515007019044  54.85322041945024  1675.991341991707
# Star 4 27.65151370655408 39.796402237632066 2083.3244330056705
# Star 5 69.69696825200862 19.057765873995702 1214.2499869864157

# %% [markdown]
# - write documentation for reading images from normal files
# - write documentation for using loupe
# - write some documentation about color scales for images (or just point them to http://docs.astropy.org/en/stable/visualization/normalization.html)?
